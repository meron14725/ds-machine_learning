# %% [markdown]
# ## PCA(主成分分析: Principal Component Analysis)
#
# ・主成分分析は次元削減の手法（機械学習の場合、ほぼ特徴量）
#
# ・主に処理の高速化とデータの可視化のために用いられる
# ![スクリーンショット 2024-07-31 8.26.59.png](attachment:10e3e1fd-c8fd-4935-a36b-19041c5447ee.png)
#
# ・PCAは、高次元から低次元へと変換するアルゴリズム
#
# ・変換して低次元にするため、全ての特徴量が必要
#
# ・なのでLassoのよう特徴量選択としての用途は限定的
# ![スクリーンショット 2024-07-31 8.31.22.png](attachment:a43b59f9-2127-4b6c-9e3f-cf230439e0a7.png)

# %% [markdown]
# ## 主成分(Principal Component)とは
#
# ・データが最もよく表している軸
#
# ・データが最も分散している軸
#
# ・データから軸の距離の合計が最も小さくなる軸
#
# ・射影後の分散が最も大きくなる軸
#
# (↑は全部同じことを言っている)
#
# ![スクリーンショット 2024-07-31 8.36.02.png](attachment:f8643282-af54-4912-9159-b7ebb65714e1.png)
#
# ・多次元のデータを圧縮するには第1主成分、第2主成分、・・・のように主成分を抽出する
#
# ・第n主成分は第n-1主成分と直行する軸の中で最も分散が大きい軸
# ![スクリーンショット 2024-07-31 8.42.28.png](attachment:e5e08fe7-1963-4e89-8ed8-4790b59e6e0f.png)
